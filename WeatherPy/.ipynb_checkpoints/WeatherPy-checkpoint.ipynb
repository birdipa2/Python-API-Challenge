# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %%
cities
# Out:
# ['adamstown',
#  'tikapur',
#  'yellowknife',
#  'parsabad',
#  'emerald',
#  'ilulissat',
#  'hermanus',
#  'bethel',
#  'lihue',
#  'saipan',
#  'edinburgh of the seven seas',
#  'sinabang',
#  'kabare',
#  'papatowai',
#  'princeville',
#  'jianshui',
#  'jenzan',
#  'puerto lempira',
#  'newman',
#  'iskateley',
#  'puerto natales',
#  'wailua homesteads',
#  'albany',
#  'isafjordur',
#  'margaret river',
#  'papao',
#  'grytviken',
#  'port alfred',
#  'port-aux-francais',
#  'longyearbyen',
#  'uturoa',
#  'tolanaro',
#  'shitanjing',
#  'hawaiian paradise park',
#  'stanley',
#  'turka',
#  'sumbawanga',
#  'polyarnyy',
#  'bardai',
#  'waitangi',
#  'ta`u',
#  'ribeira grande',
#  'galesong',
#  'fort st. john',
#  'ilek',
#  'wanning',
#  'port mathurin',
#  'as sulayyil',
#  'punta arenas',
#  'mugia',
#  'ust-nera',
#  'port elizabeth',
#  'hamilton',
#  'sabha',
#  'mogok',
#  'forbes',
#  'iqaluit',
#  'blackmans bay',
#  'tiksi',
#  'klyuchi',
#  'novyy urgal',
#  'khandyga',
#  'dunedin',
#  'vernon',
#  'eusebio ayala',
#  'lebu',
#  'taiohae',
#  'burang',
#  'enewetak',
#  'luderitz',
#  'norrtalje',
#  'remire-montjoly',
#  'cidreira',
#  'kalymnos',
#  'kalmunai',
#  'tura',
#  'shimoda',
#  'morant bay',
#  'port lincoln',
#  'amal',
#  'guerrero negro',
#  'east london',
#  'the dalles',
#  'puerto ayora',
#  'pacific grove',
#  'ushuaia',
#  'pampa',
#  'anadyr',
#  'alice springs',
#  'yulinshi',
#  'acajutla',
#  'kenai',
#  'sur',
#  "st. john's",
#  'fort bragg',
#  'bodo',
#  'petropavlovsk-kamchatsky',
#  'jinchang',
#  'thompson',
#  'west island',
#  'kodiak',
#  'akjoujt',
#  'ain arnat',
#  'puerto armuelles',
#  'bredasdorp',
#  'rio gallegos',
#  'santiago de cao',
#  'saldanha',
#  'isle of lewis',
#  'fortuna',
#  'amungan',
#  'sumberpucung',
#  'yarmouth',
#  'vardenis',
#  'marsannay-la-cote',
#  'colonia',
#  'bilibino',
#  'ulladulla',
#  'wenchang',
#  'fale old settlement',
#  'ntcheu',
#  'hilo',
#  'antsiranana',
#  'kavieng',
#  'tangalle',
#  'trairi',
#  'yerofey pavlovich',
#  'badger',
#  'varash',
#  'nova sintra',
#  'mpanda',
#  "nar'yan-mar",
#  'aasiaat',
#  'ghadamis',
#  'coquimbo',
#  'midvagur',
#  'dudinka',
#  'new norfolk',
#  'mokhotlong',
#  'phagwara',
#  'bandarbeyla',
#  'enriquillo',
#  'bloomsburg',
#  'ad dilam',
#  'san jose village',
#  'sisimiut',
#  'vilyuchinsk',
#  'vila franca do campo',
#  'el amria',
#  'nemuro',
#  'karaton',
#  'chenzhou',
#  'miyanoura',
#  'queenstown',
#  'tabou',
#  'talnakh',
#  'aracati',
#  'gadzhiyevo',
#  'fougamou',
#  'bubaque',
#  'san juan',
#  'constantia',
#  'zyrya',
#  'olinda',
#  'asau village',
#  'tadine',
#  'langarud',
#  'tugulym',
#  'georgetown',
#  'leava',
#  'sao felix do xingu',
#  'pen',
#  'kerikeri',
#  'saint-jean-de-monts',
#  'maitum',
#  'pionerskiy',
#  'masterton',
#  'palangkaraya',
#  'guatrache',
#  'ouesso',
#  'fisterra',
#  'olgii',
#  'ambodifotatra',
#  'belmonte',
#  'howrah',
#  'labuan',
#  'tocopilla',
#  'laguna',
#  'sonsorol village',
#  "kapa'a",
#  'hasaki',
#  'olonkinbyen',
#  'revelstoke',
#  'jamestown',
#  'qamdo',
#  'horta',
#  'tofol',
#  'medina',
#  'san antonio de pale',
#  'okha',
#  'tejen',
#  'saratamata',
#  'laojunmiao',
#  'avarua',
#  'sokoni',
#  'broken hill',
#  'peace river',
#  'invercargill',
#  'acarau',
#  'dargecit',
#  'chonchi',
#  'kawthoung',
#  'kourou',
#  'tres palos',
#  'bezhetsk',
#  'usinsk',
#  'zapolyarnyy',
#  'tazovsky',
#  'chardara',
#  'shache',
#  'codrington',
#  'eraan',
#  'abadan',
#  'carnarvon',
#  'santa marta de tormes',
#  'boysun',
#  'melo',
#  "nuku'alofa",
#  'manokwari',
#  'filey',
#  'puerto san carlos',
#  'saint-vith',
#  'nyurba',
#  'inhambane',
#  'atafu village',
#  'luanda',
#  'wakiso',
#  'panjakent',
#  'gao',
#  'livingstone',
#  "'ohonua",
#  'gobabis',
#  'pangai',
#  'ancud',
#  'xilin hot',
#  'mariinsk',
#  'tutoia',
#  'north battleford',
#  'lompoc',
#  'ahau',
#  'csorna',
#  'chibougamau',
#  'abu dhabi',
#  'selfoss',
#  'arteche',
#  'biala podlaska',
#  'bac lieu',
#  'rodniki',
#  'grand rapids',
#  'pacocha',
#  'abepura',
#  'ebaye',
#  'akureyri',
#  'kansanshi',
#  'walvis bay',
#  'darlowo',
#  'sitka',
#  'baotou',
#  'harper',
#  'huarmey',
#  'cargados carajos',
#  'mount isa',
#  'palmer',
#  'moranbah',
#  'micheweni',
#  'egilsstadir',
#  'north bend',
#  'khulm',
#  'dabakala',
#  'minas de marcona',
#  'saynshand',
#  'hadibu',
#  'minot air force base',
#  'subaykhan',
#  'osterburg',
#  'puerto colombia',
#  'xam nua',
#  'krosno odrzanskie',
#  'ordos',
#  'skovorodino',
#  'altai',
#  'peniche',
#  'pibor',
#  'fondettes',
#  'acapulco de juarez',
#  'aykhal',
#  'saladas',
#  'ayod',
#  'pantai cenang',
#  'kirakira',
#  'vorgashor',
#  'tarauaca',
#  'tortoli',
#  'sitangkai',
#  'at taj',
#  'puerto deseado',
#  'lusambo',
#  'alotau',
#  'glenfield park',
#  'dakhla',
#  'bainbridge',
#  'curillo',
#  'afaahiti',
#  'nebraska city',
#  'port lavaca',
#  'kitui',
#  'tabas',
#  'broome',
#  'chiang saen',
#  'mokhsogollokh',
#  'kardla',
#  'sampit',
#  'labrador city',
#  'taroa',
#  'geraldton',
#  'tevragh zeina',
#  'ca mau',
#  'an nuhud',
#  'tual',
#  'crane',
#  'shanhecun',
#  'natal',
#  'san patricio',
#  'harlingen',
#  'illapel',
#  'sao vicente',
#  'fuvahmulah',
#  'aripuana',
#  'pimentel',
#  'college',
#  'el calafate',
#  'isangel',
#  'villa gesell',
#  'tallkayf',
#  'eibau',
#  'saint-pierre',
#  'carlos chagas',
#  'manay',
#  'utrik',
#  'farafangana',
#  'yangambi',
#  'i-n-salah',
#  'cam ranh',
#  'la ronge',
#  'santa maria huatulco',
#  'zhalantun',
#  'kirensk',
#  'mejit',
#  'praia',
#  'cidade velha',
#  'pagar alam',
#  'berezovo',
#  'whitehorse',
#  'sakaiminato',
#  'caleta de carquin',
#  'sinop',
#  'tanjung selor',
#  'beyneu',
#  'merizo village',
#  'strathmore',
#  'tema',
#  'karratha',
#  'palma soriano',
#  'gebeit',
#  'suva',
#  'tazacorte',
#  'gongzhuling',
#  'margate',
#  'kapuskasing',
#  'pisco',
#  'lamar',
#  'qaqortoq',
#  'priargunsk',
#  'isla mujeres',
#  'marsa alam',
#  'ares',
#  'greenland',
#  'lloydminster',
#  'ascencion de guarayos',
#  'caqueza',
#  'seogwipo',
#  'mount hagen',
#  'reggane',
#  'vila velha',
#  'la rinconada',
#  'ercsi',
#  'weno',
#  'gaspe',
#  'nahrin',
#  'lorengau',
#  'benguela',
#  'les anglais',
#  'zalingei',
#  'taoudenni',
#  'santa ana',
#  'medellin y madero segunda seccion',
#  'keflavik',
#  'tsiombe',
#  'le perray-en-yvelines',
#  'san carlos de bariloche',
#  'turtas',
#  'kawambwa',
#  'mar del plata',
#  'takamaka',
#  'port hedland',
#  'lensk',
#  'saltillo',
#  'santo antonio do ica',
#  'cochin',
#  'ketchikan',
#  'neryungri',
#  'labasa',
#  'udachny',
#  'hithadhoo',
#  'luau',
#  'fortaleza',
#  'douglas',
#  'boda',
#  'achinsk',
#  'tonekabon',
#  'santa terezinha',
#  'kudahuvadhoo',
#  'vadso',
#  'puerto carreno',
#  'salalah',
#  'khabarovsk',
#  'gizo',
#  'hoxtolgay',
#  'tongchuanshi',
#  'namibe',
#  'freetown',
#  'bulanash',
#  'mumford',
#  'ban ao nang',
#  'toliara',
#  'praia da vitoria',
#  'cukai',
#  'northam',
#  'veymandoo',
#  'darwin',
#  'arapiraca',
#  'funafuti',
#  'vilyuysk',
#  'paita',
#  'richards bay',
#  'flying fish cove',
#  'hihifo',
#  'chernyshkovskiy',
#  'usogorsk',
#  'ixtapa',
#  'callao',
#  'berdigestyakh',
#  'ko lanta',
#  'prieska',
#  'salinas',
#  'cannonvale',
#  'lazaro cardenas',
#  'liwale',
#  'sungai penuh',
#  'sao joao da barra',
#  'port-vila',
#  'macheng',
#  'zouerate',
#  'crookston',
#  'puerto baquerizo moreno',
#  'weligama',
#  'mizque',
#  'indramayu',
#  'muisne',
#  "tobol'sk",
#  'anahuac',
#  'ongjin',
#  'arraial do cabo',
#  'luumaki',
#  'necochea',
#  'lethem',
#  'cabo san lucas',
#  'happy valley-goose bay',
#  'martapura',
#  'stonehaven',
#  'marathon',
#  'vodnyy',
#  'hobyo',
#  'bam',
#  'sakakah',
#  'arys',
#  'porto novo',
#  'magadan',
#  'bamboo flat',
#  'tranovaho',
#  'tralee',
#  'giado',
#  'saudarkrokur',
#  'ambon',
#  'sao cristovao',
#  'tataouine',
#  'lautoka',
#  'loiza',
#  'nuuk',
#  'alo',
#  'rikaze',
#  'moanda',
#  'diawara',
#  'oualidia',
#  'touros',
#  'ciudad lazaro cardenas',
#  'san julian',
#  'wellington',
#  'isiro',
#  'tuy hoa',
#  'garhiyasin',
#  'alofi',
#  'joao pessoa',
#  'muncar',
#  'labytnangi',
#  'as sars',
#  'virrat',
#  'turpan',
#  'novyy urengoy',
#  'rongelap',
#  'shizunai-furukawacho',
#  'belyy yar',
#  'yeosu',
#  'seshcha',
#  'caxito',
#  'buka',
#  'faya-largeau',
#  'ghat',
#  'las terrenas',
#  'idri',
#  'paya',
#  'lagonegro',
#  'gisborne',
#  'coahuayana de hidalgo',
#  "ust'-ilimsk",
#  'dunda',
#  'guapore',
#  'carbonear',
#  'spring creek',
#  'vaux-le-penil',
#  'cide',
#  'timbuktu',
#  'saint-leu',
#  'mountain home',
#  'mahabe',
#  'umm kaddadah',
#  'punta del este',
#  'sint michiel liber',
#  'kaseda-shirakame',
#  'barah',
#  'urangan',
#  'asbe teferi',
#  'talakan',
#  'boa vista',
#  'cadale',
#  'devils lake',
#  'venado',
#  'glendive',
#  'dryden',
#  'whangarei',
#  'kapit',
#  'kutum',
#  'birao',
#  'galliano',
#  'prince george',
#  'dwarka',
#  'saint-philippe',
#  'farmville',
#  'kingston',
#  'prince rupert',
#  'leh',
#  'mata-utu',
#  'sao jose da coroa grande',
#  'rabigh',
#  'pandan',
#  'mahibadhoo',
#  'manuel ojinaga',
#  'pariaman']

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{url}q={city}&appid=41a66e302dc647c3b4a25ebf0a152477&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | tikapur
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | parsabad
# Processing Record 5 of Set 1 | emerald
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | lihue
# Processing Record 10 of Set 1 | saipan
# Processing Record 11 of Set 1 | edinburgh of the seven seas
# Processing Record 12 of Set 1 | sinabang
# Processing Record 13 of Set 1 | kabare
# Processing Record 14 of Set 1 | papatowai
# Processing Record 15 of Set 1 | princeville
# Processing Record 16 of Set 1 | jianshui
# Processing Record 17 of Set 1 | jenzan
# Processing Record 18 of Set 1 | puerto lempira
# Processing Record 19 of Set 1 | newman
# Processing Record 20 of Set 1 | iskateley
# Processing Record 21 of Set 1 | puerto natales
# Processing Record 22 of Set 1 | wailua homesteads
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | isafjordur
# Processing Record 25 of Set 1 | margaret river
# Processing Record 26 of Set 1 | papao
# Processing Record 27 of Set 1 | grytviken
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | port-aux-francais
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | uturoa
# Processing Record 32 of Set 1 | tolanaro
# Processing Record 33 of Set 1 | shitanjing
# Processing Record 34 of Set 1 | hawaiian paradise park
# Processing Record 35 of Set 1 | stanley
# Processing Record 36 of Set 1 | turka
# Processing Record 37 of Set 1 | sumbawanga
# Processing Record 38 of Set 1 | polyarnyy
# Processing Record 39 of Set 1 | bardai
# Processing Record 40 of Set 1 | waitangi
# Processing Record 41 of Set 1 | ta`u
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 
# Processing Record 5 of Set 5 | broken hill
# Processing Record 6 of Set 5 | peace river
# Processing Record 7 of Set 5 | invercargill
# Processing Record 8 of Set 5 | acarau
# Processing Record 9 of Set 5 | dargecit
# Processing Record 10 of Set 5 | chonchi
# Processing Record 11 of Set 5 | kawthoung
# City not found. Skipping...
# Processing Record 12 of Set 5 | kourou
# Processing Record 13 of Set 5 | tres palos
# Processing Record 14 of Set 5 | bezhetsk
# Processing Record 15 of Set 5 | usinsk
# Processing Record 16 of Set 5 | zapolyarnyy
# Processing Record 17 of Set 5 | tazovsky
# Processing Record 18 of Set 5 | chardara
# Processing Record 19 of Set 5 | shache
# Processing Record 20 of Set 5 | codrington
# Processing Record 21 of Set 5 | eraan
# Processing Record 22 of Set 5 | abadan
# Processing Record 23 of Set 5 | carnarvon
# Processing Record 24 of Set 5 | santa marta de tormes
# Processing Record 25 of Set 5 | boysun
# Processing Record 26 of Set 5 | melo
# Processing Record 27 of Set 5 | nuku'alofa
# Processing Record 28 of Set 5 | manokwari
# Processing Record 29 of Set 5 | filey
# Processing Record 30 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 31 of Set 5 | saint-vith
# Processing Record 32 of Set 5 | nyurba
# Processing Record 33 of Set 5 | inhambane
# Processing Record 34 of Set 5 | atafu village
# Processing Record 35 of Set 5 | luanda
# Processing Record 36 of Set 5 | wakiso
# Processing Record 37 of Set 5 | panjakent
# Processing Record 38 of Set 5 | gao
# Processing Record 39 of Set 5 | livingstone
# Processing Record 40 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 41 of Set 5 | gobabis
# Processing Record 42 of Set 5 | pangai
# Processing Record 43 of Set 5 | ancud
# Processing Record 44 of Set 5 | xilin hot
# Processing Record 45 of Set 5 | mariinsk
# Processing Record 46 of Set 5 | tutoia
# Processing Record 47 of Set 5 | north battleford
# Processing Record 48 of Set 5 | lompoc
# Processing Record 49 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 0 of Set 6 | csorna
# Processing Record 1 of Set 6 | chibougamau
# Processing Record 2 of Set 6 | abu dhabi
# Processing Record 3 of Set 6 | selfoss
# Processing Record 4 of Set 6 | arteche
# Processing Record 5 of Set 6 | biala podlaska
# Processing Record 6 of Set 6 | bac lieu
# Processing Record 7 of Set 6 | rodniki
# Processing Record 8 of Set 6 | grand rapids
# Processing Record 9 of Set 6 | pacocha
# Processing Record 10 of Set 6 | abepura
# Processing Record 11 of Set 6 | ebaye
# Processing Record 12 of Set 6 | akureyri
# Processing Record 13 of Set 6 | kansanshi
# Processing Record 14 of Set 6 | walvis bay
# Processing Record 15 of Set 6 | darlowo
# Processing Record 16 of Set 6 | sitka
# Processing Record 17 of Set 6 | baotou
# Processing Record 18 of Set 6 | harper
# Processing Record 19 of Set 6 | huarmey
# Processing Record 20 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 21 of Set 6 | mount isa
# Processing Record 22 of Set 6 | palmer
# Processing Record 23 of Set 6 | moranbah
# Processing Record 24 of Set 6 | micheweni
# Processing Record 25 of Set 6 | egilsstadir
# Processing Record 26 of Set 6 | north bend
# Processing Record 27 of Set 6 | khulm
# Processing Record 28 of Set 6 | dabakala
# Processing Record 29 of Set 6 | minas de marcona
# Processing Record 30 of Set 6 | saynshand
# Processing Record 31 of Set 6 | hadibu
# Processing Record 32 of Set 6 | minot air force base
# Processing Record 33 of Set 6 | subaykhan
# Processing Record 34 of Set 6 | osterburg
# Processing Record 35 of Set 6 | puerto colombia
# Processing Record 36 of Set 6 | xam nua
# Processing Record 37 of Set 6 | krosno odrzanskie
# Processing Record 38 of Set 6 | ordos
# City not found. Skipping...
# Processing Record 39 of Set 6 | skovorodino
# Processing Record 40 of Set 6 | altai
# Processing Record 41 of Set 6 | peniche
# Processing Record 42 of Set 6 | pibor
# City not found. Skipping...
# Processing Record 43 of Set 6 | fondettes
# Processing Record 44 of Set 6 | acapulco de juarez
# Processing Record 45 of Set 6 | aykhal
# Processing Record 46 of Set 6 | saladas
# Processing Record 47 of Set 6 | ayod
# City not found. Skipping...
# Processing Record 48 of Set 6 | pantai cenang
# City not found. Skipping...
# Processing Record 49 of Set 6 | kirakira
# Processing Record 0 of Set 7 | vorgashor
# Processing Record 1 of Set 7 | tarauaca
# Processing Record 2 of Set 7 | tortoli
# Processing Record 3 of Set 7 | sitangkai
# Processing Record 4 of Set 7 | at taj
# Processing Record 5 of Set 7 | puerto deseado
# Processing Record 6 of Set 7 | lusambo
# Processing Record 7 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 7 | glenfield park
# Processing Record 9 of Set 7 | dakhla
# Processing Record 10 of Set 7 | bainbridge
# Processing Record 11 of Set 7 | curillo
# Processing Record 12 of Set 7 | afaahiti
# Processing Record 13 of Set 7 | nebraska city
# Processing Record 14 of Set 7 | port lavaca
# Processing Record 15 of Set 7 | kitui
# Processing Record 16 of Set 7 | tabas
# Processing Record 17 of Set 7 | broome
# Processing Record 18 of Set 7 | chiang saen
# Processing Record 19 of Set 7 | mokhsogollokh
# Processing Record 20 of Set 7 | kardla
# Processing Record 21 of Set 7 | sampit
# Processing Record 22 of Set 7 | labrador city
# Processing Record 23 of Set 7 | taroa
# Processing Record 24 of Set 7 | geraldton
# Processing Record 25 of Set 7 | tevragh zeina
# City not found. Skipping...
# Processing Record 26 of Set 7 | ca mau
# Processing Record 27 of Set 7 | an nuhud
# Processing Record 28 of Set 7 | tual
# Processing Record 29 of Set 7 | crane
# Processing Record 30 of Set 7 | shanhecun
# Processing Record 31 of Set 7 | natal
# Processing Record 32 of Set 7 | san patricio
# Processing Record 33 of Set 7 | harlingen
# Processing Record 34 of Set 7 | illapel
# Processing Record 35 of Set 7 | sao vicente
# Processing Record 36 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 37 of Set 7 | aripuana
# Processing Record 38 of Set 7 | pimentel
# Processing Record 39 of Set 7 | college
# Processing Record 40 of Set 7 | el calafate
# Processing Record 41 of Set 7 | isangel
# Processing Record 42 of Set 7 | villa gesell
# Processing Record 43 of Set 7 | tallkayf
# Processing Record 44 of Set 7 | eibau
# Processing Record 45 of Set 7 | saint-pierre
# Processing Record 46 of Set 7 | carlos chagas
# Processing Record 47 of Set 7 | manay
# Processing Record 48 of Set 7 | utrik
# Processing Record 49 of Set 7 | farafangana
# Processing Record 0 of Set 8 | yangambi
# Processing Record 1 of Set 8 | i-n-salah
# Processing Record 2 of Set 8 | cam ranh
# Processing Record 3 of Set 8 | la ronge
# Processing Record 23 of Set 9 | hithadhoo
# Processing Record 24 of Set 9 | luau
# Processing Record 25 of Set 9 | fortaleza
# Processing Record 26 of Set 9 | douglas
# Processing Record 27 of Set 9 | boda
# Processing Record 28 of Set 9 | achinsk
# Processing Record 29 of Set 9 | tonekabon
# Processing Record 30 of Set 9 | santa terezinha
# Processing Record 31 of Set 9 | kudahuvadhoo
# Processing Record 32 of Set 9 | vadso
# Processing Record 33 of Set 9 | puerto carreno
# Processing Record 34 of Set 9 | salalah
# Processing Record 35 of Set 9 | khabarovsk
# Processing Record 36 of Set 9 | gizo
# Processing Record 37 of Set 9 | hoxtolgay
# City not found. Skipping...
# Processing Record 38 of Set 9 | tongchuanshi
# Processing Record 39 of Set 9 | namibe
# Processing Record 40 of Set 9 | freetown
# Processing Record 41 of Set 9 | bulanash
# Processing Record 42 of Set 9 | mumford
# Processing Record 43 of Set 9 | ban ao nang
# Processing Record 44 of Set 9 | toliara
# Processing Record 45 of Set 9 | praia da vitoria
# Processing Record 46 of Set 9 | cukai
# Processing Record 47 of Set 9 | northam
# Processing Record 48 of Set 9 | veymandoo
# City not found. Skipping...
# Processing Record 49 of Set 9 | darwin
# Processing Record 0 of Set 10 | arapiraca
# Processing Record 1 of Set 10 | funafuti
# Processing Record 2 of Set 10 | vilyuysk
# Processing Record 3 of Set 10 | paita
# Processing Record 4 of Set 10 | richards bay
# Processing Record 5 of Set 10 | flying fish cove
# Processing Record 6 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 10 | chernyshkovskiy
# Processing Record 8 of Set 10 | usogorsk
# Processing Record 9 of Set 10 | ixtapa
# Processing Record 10 of Set 10 | callao
# Processing Record 11 of Set 10 | berdigestyakh
# Processing Record 12 of Set 10 | ko lanta
# Processing Record 13 of Set 10 | prieska
# Processing Record 14 of Set 10 | salinas
# Processing Record 15 of Set 10 | cannonvale
# Processing Record 16 of Set 10 | lazaro cardenas
# Processing Record 17 of Set 10 | liwale
# Processing Record 18 of Set 10 | sungai penuh
# Processing Record 19 of Set 10 | sao joao da barra
# Processing Record 20 of Set 10 | port-vila
# Processing Record 21 of Set 10 | macheng
# Processing Record 22 of Set 10 | zouerate
# Processing Record 23 of Set 10 | crookston
# Processing Record 24 of Set 10 | puerto baquerizo moreno
# Processing Record 25 of Set 10 | weligama
# Processing Record 26 of Set 10 | mizque
# Processing Record 27 of Set 10 | indramayu
# Processing Record 28 of Set 10 | muisne
# Processing Record 29 of Set 10 | tobol'sk
# Processing Record 30 of Set 10 | anahuac
# Processing Record 31 of Set 10 | ongjin
# Processing Record 32 of Set 10 | arraial do cabo
# Processing Record 33 of Set 10 | luumaki
# Processing Record 34 of Set 10 | necochea
# Processing Record 35 of Set 10 | lethem
# Processing Record 36 of Set 10 | cabo san lucas
# Processing Record 37 of Set 10 | happy valley-goose bay
# Processing Record 38 of Set 10 | martapura
# Processing Record 39 of Set 10 | stonehaven
# Processing Record 40 of Set 10 | marathon
# Processing Record 41 of Set 10 | vodnyy
# Processing Record 42 of Set 10 | hobyo
# Processing Record 43 of Set 10 | bam
# Processing Record 44 of Set 10 | sakakah
# Processing Record 45 of Set 10 | arys
# Processing Record 46 of Set 10 | porto novo
# Processing Record 47 of Set 10 | magadan
# Processing Record 48 of Set 10 | bamboo flat
# Processing Record 49 of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 0 of Set 11 | tralee
# Processing Record 1 of Set 11 | giado
# Processing Record 2 of Set 11 | saudarkrokur
# Processing Record 3 of Set 11 | ambon
# Processing Record 4 of Set 11 | sao cristovao
# Processing Record 5 of Set 11 | tataouine
# Processing Record 6 of Set 11 | lautoka
# Processing Record 7 of Set 11 | loiza
# Processing Record 8 of Set 11 | nuuk
# Processing Record 9 of Set 11 | alo
# Processing Record 10 of Set 11 | rikaze
# Processing Record 11 of Set 11 | moanda
# Processing Record 12 of Set 11 | diawara
# Processing Record 13 of Set 11 | oualidia
# City not found. Skipping...
# Processing Record 14 of Set 11 | touros
# Processing Record 15 of Set 11 | ciudad lazaro cardenas
# Processing Record 16 of Set 11 | san julian
# Processing Record 17 of Set 11 | wellington
# Processing Record 18 of Set 11 | isiro
# Processing Record 19 of Set 11 | tuy hoa
# Processing Record 20 of Set 11 | garhiyasin
# Processing Record 21 of Set 11 | alofi
# Processing Record 22 of Set 11 | joao pessoa
# Processing Record 23 of Set 11 | muncar
# Processing Record 24 of Set 11 | labytnangi
# Processing Record 25 of Set 11 | as sars
# Processing Record 26 of Set 11 | virrat
# Processing Record 27 of Set 11 | turpan
# Processing Record 28 of Set 11 | novyy urengoy
# Processing Record 29 of Set 11 | rongelap
# Processing Record 30 of Set 11 | shizunai-furukawacho
# Processing Record 31 of Set 11 | belyy yar
# Processing Record 32 of Set 11 | yeosu
# Processing Record 33 of Set 11 | seshcha
# Processing Record 34 of Set 11 | caxito
# Processing Record 35 of Set 11 | buka
# Processing Record 36 of Set 11 | faya-largeau
# Processing Record 37 of Set 11 | ghat
# Processing Record 38 of Set 11 | las terrenas
# Processing Record 39 of Set 11 | idri
# Processing Record 40 of Set 11 | paya
# Processing Record 41 of Set 11 | lagonegro
# Processing Record 42 of Set 11 | gisborne
# Processing Record 43 of Set 11 | coahuayana de hidalgo
# Processing Record 44 of Set 11 | ust'-ilimsk
# Processing Record 45 of Set 11 | dunda
# Processing Record 46 of Set 11 | guapore
# Processing Record 47 of Set 11 | carbonear
# Processing Record 48 of Set 11 | spring creek
# Processing Record 49 of Set 11 | vaux-le-penil
# Processing Record 0 of Set 12 | cide
# Processing Record 1 of Set 12 | timbuktu
# Processing Record 2 of Set 12 | saint-leu
# Processing Record 3 of Set 12 | mountain home
# Processing Record 4 of Set 12 | mahabe
# City not found. Skipping...
# Processing Record 5 of Set 12 | umm kaddadah
# Processing Record 6 of Set 12 | punta del este
# Processing Record 7 of Set 12 | sint michiel liber
# Processing Record 8 of Set 12 | kaseda-shirakame
# Processing Record 9 of Set 12 | barah
# Processing Record 10 of Set 12 | urangan
# Processing Record 11 of Set 12 | asbe teferi
# Processing Record 12 of Set 12 | talakan
# Processing Record 13 of Set 12 | boa vista
# Processing Record 14 of Set 12 | cadale
# Processing Record 15 of Set 12 | devils lake
# Processing Record 16 of Set 12 | venado
# Processing Record 17 of Set 12 | glendive
# Processing Record 18 of Set 12 | dryden
# Processing Record 19 of Set 12 | whangarei
# Processing Record 20 of Set 12 | kapit
# Processing Record 21 of Set 12 | kutum
# Processing Record 22 of Set 12 | birao
# Processing Record 23 of Set 12 | galliano
# Processing Record 24 of Set 12 | prince george
# Processing Record 25 of Set 12 | dwarka
# Processing Record 26 of Set 12 | saint-philippe
# Processing Record 27 of Set 12 | farmville
# Processing Record 28 of Set 12 | kingston
# Processing Record 29 of Set 12 | prince rupert
# Processing Record 30 of Set 12 | leh
# Processing Record 31 of Set 12 | mata-utu
# Processing Record 32 of Set 12 | sao jose da coroa grande
# Processing Record 33 of Set 12 | rabigh
# Processing Record 34 of Set 12 | pandan
# Processing Record 35 of Set 12 | mahibadhoo
# Processing Record 36 of Set 12 | manuel ojinaga
# City not found. Skipping...
# Processing Record 37 of Set 12 | pariaman
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
from pprint import pprint
pprint(city_weather)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -0.619, 'lon': 100.12},
#  'dt': 1681699019,
#  'id': 1632334,
#  'main': {'feels_like': 30.33,
#           'grnd_level': 1011,
#           'humidity': 67,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 28.03,
#           'temp_max': 28.03,
#           'temp_min': 28.03},
#  'name': 'Pariaman',
#  'sys': {'country': 'ID',
#          'id': 9423,
#          'sunrise': 1681686966,
#          'sunset': 1681730517,
#          'type': 1},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 225, 'gust': 1.05, 'speed': 1.26}}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          555
# Lat           555
# Lng           555
# Max Temp      555
# Humidity      555
# Cloudiness    555
# Wind Speed    555
# Country       555
# Date          555
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    adamstown -25.0660 -130.1015     25.74        83           4        6.20
# 1      tikapur  28.5000   81.1333     33.76        12           0        1.70
# 2  yellowknife  62.4560 -114.3525      6.29        49          40        5.66
# 3     parsabad  39.6482   47.9174      7.57        72         100        4.82
# 4      emerald -23.5333  148.1667     25.75        61          20        3.51
#
#   Country        Date
# 0      PN  1681698820
# 1      NP  1681698821
# 2      CA  1681698822
# 3      IR  1681698822
# 4      AU  1681698822

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          adamstown -25.0660 -130.1015     25.74        83           4
# 1            tikapur  28.5000   81.1333     33.76        12           0
# 2        yellowknife  62.4560 -114.3525      6.29        49          40
# 3           parsabad  39.6482   47.9174      7.57        72         100
# 4            emerald -23.5333  148.1667     25.75        61          20
#
#          Wind Speed Country        Date
# City_ID
# 0              6.20      PN  1681698820
# 1              1.70      NP  1681698821
# 2              5.66      CA  1681698822
# 3              4.82      IR  1681698822
# 4              3.51      AU  1681698822

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
x_values = [city['Lat'] for city in city_data]
y_values = [city['Max Temp'] for city in city_data]

plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Max Latitude vs. Temperature ()')
plt.grid()
plt.show()
# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
x_values = [city['Lat'] for city in city_data]
y_values = [city['Humidity'] for city in city_data]

plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity ()')
plt.grid()
# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
x_values = [city['Lat'] for city in city_data]
y_values = [city['Cloudiness'] for city in city_data]

plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness ()')
plt.grid()
# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
x_values = [city['Lat'] for city in city_data]
y_values = [city['Wind Speed'] for city in city_data]

plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed ()')
plt.grid()
# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
